# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from datetime import datetime
from dateutil.parser import parse

#%matplotlib inline

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
train_data = 'train.csv'
train_data_v2= 'train_v2.csv'
transaction_data = 'transactions.csv'
transaction_data_v2='transactions_v2.csv'
member_data = 'members_v2.csv'

# %%
parse_dates = ['transaction_date', 'membership_expire_date']
parse_dates2 = ['registration_init_time']
member = pd.read_csv(member_data, index_col='msno', parse_dates=parse_dates2)
train=pd.read_csv(train_data, index_col ='msno')
train2=pd.read_csv(train_data_v2, index_col ='msno')

# %%
merged_train = pd.concat([train, train2])

# %%
#member 와 train data merge

table=member.join(merged_train)

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1452930 entries, +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o= to zzzF1KsGfHH3qI6qiSNSXC35UXmVKMVFdxkp7xmDMc0=
# Data columns (total 6 columns):
# city                      1452930 non-null int64
# bd                        1452930 non-null int64
# gender                    570446 non-null object
# registered_via            1452930 non-null int64
# registration_init_time    1452930 non-null datetime64[ns]
# is_churn                  1396126 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 77.6+ MB

# %%
table.registration_init_time.hist()

# %%
pd.value_counts(table.gender)
# Out:
# male      302019
# female    268427
# Name: gender, dtype: int64

# %%
bins=[0,18,25,35,60,100]

# %%
cutted = pd.cut(test.bd, bins)

# %%
table.groupby('bins')['is_churn'].mean()
# Out:
# bins
# (0, 18]      0.067711
# (18, 25]     0.037524
# (25, 35]     0.019045
# (35, 60]     0.013791
# (60, 100]    0.017184
# Name: is_churn, dtype: float64

# %%
table
# Out:
#                                               city  bd  gender  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=     1   0     NaN
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=     1   0     NaN
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=     1   0     NaN
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=     1   0     NaN
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=    18  21    male
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=    18  21    male
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=     1   0     NaN
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=     1   0     NaN
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=     1   0     NaN
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=     1   0     NaN
# ++0nOC7BmrUTtcSboRORfg6ZXTajnBDt1f/SEgH6ONo=    13  25    male
# ++1G0wVY14Lp0VXak1ymLhPUdXPSFJVBnjWwzGxBKJs=     1   0     NaN
# ++1G0wVY14Lp0VXak1ymLhPUdXPSFJVBnjWwzGxBKJs=     1   0     NaN
# ++1GCIyXZO7834NjDKmcK1lBVLQi9PsN6sOC7wfW+8g=     1   0     NaN
# ...

# %%
table['bins']=cutted

# %%
table
# Out:
#                                               city  bd  gender  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=     1   0     NaN
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=     1   0     NaN
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=     1   0     NaN
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=     1   0     NaN
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=    18  21    male
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=    18  21    male
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=     1   0     NaN
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=     1   0     NaN
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=     1   0     NaN
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=     1   0     NaN
# ++0nOC7BmrUTtcSboRORfg6ZXTajnBDt1f/SEgH6ONo=    13  25    male
# ++1G0wVY14Lp0VXak1ymLhPUdXPSFJVBnjWwzGxBKJs=     1   0     NaN
# ++1G0wVY14Lp0VXak1ymLhPUdXPSFJVBnjWwzGxBKJs=     1   0     NaN
# ++1GCIyXZO7834NjDKmcK1lBVLQi9PsN6sOC7wfW+8g=     1   0     NaN
# ...

# %%
pd.value_counts(cutted)
# Out:
# (25, 35]     239346
# (18, 25]     167002
# (35, 60]     127061
# (0, 18]       25909
# (60, 100]      3738
# Name: bd, dtype: int64

# %%
pd.value_counts(test.bd)
# Out:
#  0       889122
#  27       32456
#  26       30941
#  25       29391
#  28       28832
#  24       28768
#  29       28052
#  23       27149
#  22       25678
#  30       24450
#  21       22013
#  31       21529
#  32       20551
#  20       19676
#  33       19001
#  34       17432
#  35       16102
#  36       14816
#  19       14327
#  37       13267
#  18       11789
#  38       11567
#  39       10117
#  40        8642
#  17        8618
#  41        8132
#  42        6807
#  43        5863
#  44        5190
#  45        4853
#           ...
#  129          2
#  123          2
#  122          2
#  121          2
#  113          2
#  99           2
# -5            2
#  340          2
#  1421         2
#  786          2
#  930          2
#  950          2
#  1970         2
# -3152         2
#  945          2
#  944          2
#  936          2
#  1820         2
#  934          2
#  906          2
#  837          2
#  826          2
#  821          2
#  820          2
# ...

# %%
table.groupby('gender').hist()
# Out:
# gender
# female    [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# male      [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# dtype: object

# %%
plt.scatter(table.bd, table.is_churn)

# %%
time=table.registration_init_time
churn=table.is_churn
