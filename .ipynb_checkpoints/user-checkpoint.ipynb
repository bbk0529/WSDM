# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from datetime import datetime
from dateutil.parser import parse

# %matplotlib inline

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# !ls
# Out:
# members_v2.csv		  transaction.ipynb    user_logs.csv
# sample_submission_v2.csv  transactions.csv     user_logs_v2.csv
# train.csv		  transactions_v2.csv
# train_v2.csv		  user.ipynb

# %%
train_data = 'train.csv'
train_data_v2= 'train_v2.csv'
transaction_data = 'transactions.csv'
transaction_data_v2='transactions_v2.csv'

# %%
#Reading datas from csv files 
parse_dates = ['transaction_date', 'membership_expire_date']
train=pd.read_csv(train_data, index_col ='msno')
train2=pd.read_csv(train_data_v2, index_col ='msno')
#ransaction = pd.read_csv(transaction_data, nrows=100, index_col='msno', parse_dates=parse_dates)
transaction = pd.read_csv(transaction_data, nrows=100, index_col='msno', parse_dates=parse_dates)
transaction_v2 = pd.read_csv(transaction_data_v2, index_col='msno', parse_dates=parse_dates)

# %%
merged_train = pd.concat([train, train2])

# %%
merged_transaction=pd.concat([transaction, transaction_v2])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-27-e61e8deb4caf> in <module>()
# ----> 1 merged_transaction=pd.concat([transaction, transaction_v2])
#
# ~/dev/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     205                        verify_integrity=verify_integrity,
#     206                        copy=copy)
# --> 207     return op.get_result()
#     208
#     209
#
# ~/dev/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     405             new_data = concatenate_block_managers(
#     406                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 407                 copy=self.copy)
#     408             if not self.copy:
#     409                 new_data._consolidate_inplace()
#
# ...

# %%
merged_train = pd.concat([train, train2])
merged_transaction=pd.concat([transaction, transaction_v2])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-20-64c301f581f6> in <module>()
#       1 Merged_train = pd.concat([train, train2])
# ----> 2 merged_transaction=pd.concat([transaction, transaction_v2])
#
# ~/dev/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     205                        verify_integrity=verify_integrity,
#     206                        copy=copy)
# --> 207     return op.get_result()
#     208
#     209
#
# ~/dev/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     405             new_data = concatenate_block_managers(
#     406                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 407                 copy=self.copy)
#     408             if not self.copy:
# ...

# %%
#join on 'Index  -msno' 
joined_Table=transaction.join(train)

# %%
transaction.shape
# Out:
# (21547746, 8)

# %%
joined_Table.shape
# Out:
# (21547746, 9)

# %%
train.size
pd.value_counts(train.is_churn)
# Out:
# 992931
# 0    929460
# 1     63471
# Name: is_churn, dtype: int64

# %%
transaction.size
pd.value_counts(transaction.is_auto_renew)
# Out:
# 172381968
# 1    18357950
# 0     3189796
# Name: is_auto_renew, dtype: int64

# %%
joined_Table
# Out:
#                                               payment_method_id  \
# msno
# +++FOrTS7ab3tIgIh8eWwX4FqRv8w/FoiOuyXsFvphY=                 35
# +++IZseRRiQS9aaSkH6cMYU6bGDcxUieAi/tH67sC5s=                 38
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 41
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 41
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 41
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 41
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# ...

# %%
pd.value_counts(transaction.payment_plan_days).plot(kind='bar')

# %%
pd.value_counts(transaction.plan_list_price)
pd.value_counts(transaction.actual_amount_paid)
# Out:
# 149     12536656
# 99       4853433
# 0        1498544
# 129      1144459
# 180       682533
# 150       382860
# 894       109879
# 100        80285
# 1788       80066
# 536        43506
# 119        32280
# 480        22977
# 1599       11463
# 477        10847
# 35          7410
# 799         6264
# 300         5828
# 120         5821
# 1200        5486
# 298         5272
# 930         5082
# 447         4348
# 134         3743
# 450         1455
# 500         1185
# 50          1051
# 699          915
# 1000         750
# 124          598
# 350          587
# 131          374
# 105          348
# 400          342
# 70           250
# 143          143
# 2000         118
# 1            113
# 1150         103
# 126           99
# 596           70
# 10            67
# 15            50
# 210           26
# 265           21
# 1520          13
# 800           11
# 30             6
# 760            3
# 600            3
# 1825           2
# 44             1
# ...

# %%
pd.value_counts(transaction.index)
# Out:
# xm6fmAfgZx1OYUXaJuHOObD0H2EAtIktv9NYIVlaTf4=    71
# ur5l+RJ9n6L7h96PqgBIOfgFxSM95YzhdrA8xS1NvRQ=    64
# Gm6nq94d1kn48YpqQzvWshpfQ2F218e+ISrtxjaA/EI=    64
# dnjJq1LhXBehL0VyhlHzYKKqVwMj7M9j7E7rRXY0HqE=    63
# mxpRHNaHkFo7IfnKAqUaA8xrgpaDnnZDsjJvw8gH+FQ=    63
# lZo4HG6fI31GEY/uijC4/JSCMhGSUT32iRYptqs7XtY=    62
# Mjp5uPtRQPFUiMfw+rWecb2EGoo69dc6t1gSBRgz60c=    61
# tWuakM8NS9fiWC5aD7zc36zw2U1BW54OXTWGEbdrnMI=    59
# 791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=    58
# a9qvbz8KifymI7eTNDA/j/BDGpbx2RBGlFn9T35nN2c=    55
# s9TssUQjN+WI+HvdknTJbhIgc0/SY+7vCsmWjkhLXAo=    54
# gIc4eYCIcu4NVYX6RC/pYtMxORCGcCY8ftNyZQ6GXhk=    54
# CRsQ9f3xwdwV3xWjfMXRalzu57lDhvw2isgp9EYRgEI=    54
# Dsr+SqRiw0yQU60AqOqDdOwMjjPWw133GDrk7P3JzBw=    53
# MixNMEf4Z4pRCZR+V/+QCeHXk6cTAC5n56Dug7oU/BM=    53
# SS/obq5EgDla6OM4ZJ3sKIZZD1g3tDQO+LDZU7bEsi0=    53
# wZfaskjMFnyf/PFcQbe3dQORq1outZc0LTF1KDRpJfs=    53
# +VqL3uIERyJrTF7Q9IjlrYkrWnSod6jokGMDPltUBuU=    52
# ...

# %%
pd.value_counts(transaction.payment_method_id)
# Out:
# 41    11526454
# 40     2225283
# 38     1703590
# 39     1466655
# 37     1007689
# 36      855115
# 34      731539
# 35      541399
# 33      411164
# 31      252342
# 30      160957
# 32      146481
# 29      113885
# 28       95733
# 27       62525
# 23       42386
# 19       32073
# 20       28278
# 21       22883
# 22       20130
# 24       16196
# 18       16177
# 25       13780
# 14       13621
# 16       11064
# 17        7437
# 13        6571
# 26        4591
# 12        3834
# 11        2129
# 15        1479
# 10        1326
# 7         1094
# 8          657
# 5          474
# 6          466
# 3          210
# 2           52
# 4           15
# 1           12
# Name: payment_method_id, dtype: int64

# %%
grouped=joined_Table.groupby(joined_Table.index)

# %%
g_is_churn=joined_Table.groupby(joined_Table.is_churn)

# %%
g_is_churn.describe()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-174-7776c8a0d12e> in <module>()
# ----> 1 g_is_churn.describe()
#
# ~/dev/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in describe(self, **kwargs)
#    1217     def describe(self, **kwargs):
#    1218         self._set_group_selection()
# -> 1219         result = self.apply(lambda x: x.describe(**kwargs))
#    1220         if self.axis == 1:
#    1221             return result.T
#
# ~/dev/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#     714         # ignore SettingWithCopy here in case the user mutates
#     715         with option_context('mode.chained_assignment', None):
# --> 716             return self._python_apply_general(f)
#     717
#     718     def _python_apply_general(self, f):
#
# ...

# %%
grouped.mean()
# Out:
#                                               payment_method_id  \
# msno
# +++FOrTS7ab3tIgIh8eWwX4FqRv8w/FoiOuyXsFvphY=          35.000000
# +++IZseRRiQS9aaSkH6cMYU6bGDcxUieAi/tH67sC5s=          38.000000
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=          41.000000
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=          39.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=          41.000000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=          41.000000
# ++/Gw1B9K+XOlB3hLTloeUK2QlCa2m+BJ8TrzGf7djI=          39.111111
# ++/TR7WI15q2ZCtOXmoap7jR+kEhbMVE5swOqsfqpqI=          11.000000
# ++/UDNo9DLrxT8QVGiDi1OnWfczAdEwThaVyD0fXO50=          39.000000
# ++/ZHqwUNa7U21Qz+zqteiXlZapxey86l6eEorrak/g=          14.000000
# ++/gTmVgKUbNFmsTiriZdWV1uZIrLXCUiEWN0fEU6BM=          41.000000
# ++/imsKMXignukHBIRfOhocobbR8Qk1Ew5mhjOCJg5A=          35.000000
# ++0+IdHga8fCSioOVpU8K7y4Asw8AveIApVH2r9q9yY=          32.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=          41.000000
# ...

# %%
joined_Table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21547746 entries, +++FOrTS7ab3tIgIh8eWwX4FqRv8w/FoiOuyXsFvphY= to zzzyOgMk9MljCerbCCYrVtvu85aSCiy7yCMjAEgNYMs=
# Data columns (total 9 columns):
# payment_method_id         int64
# payment_plan_days         int64
# plan_list_price           int64
# actual_amount_paid        int64
# is_auto_renew             int64
# transaction_date          datetime64[ns]
# membership_expire_date    datetime64[ns]
# is_cancel                 int64
# is_churn                  float64
# dtypes: datetime64[ns](2), float64(1), int64(6)
# memory usage: 1.6+ GB

# %%
joined_Table.describe()
# Out:
#        payment_method_id  payment_plan_days  plan_list_price  \
# count       2.154775e+07       2.154775e+07     2.154775e+07
# mean        3.893310e+01       3.133906e+01     1.398850e+02
# std         3.507936e+00       3.035649e+01     1.309647e+02
# min         1.000000e+00       0.000000e+00     0.000000e+00
# 25%         3.800000e+01       3.000000e+01     9.900000e+01
# 50%         4.100000e+01       3.000000e+01     1.490000e+02
# 75%         4.100000e+01       3.000000e+01     1.490000e+02
# max         4.100000e+01       4.500000e+02     2.000000e+03
#
#        actual_amount_paid  is_auto_renew     is_cancel      is_churn
# count        2.154775e+07   2.154775e+07  2.154775e+07  1.588315e+07
# mean         1.419873e+02   8.519661e-01  3.976523e-02  4.316342e-02
# std          1.324824e+02   3.551336e-01  1.954072e-01  2.032249e-01
# min          0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00
# 25%          9.900000e+01   1.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
joined_Table
# Out:
#                                               payment_method_id  \
# msno
# +++FOrTS7ab3tIgIh8eWwX4FqRv8w/FoiOuyXsFvphY=                 35
# +++IZseRRiQS9aaSkH6cMYU6bGDcxUieAi/tH67sC5s=                 38
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 41
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 41
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 41
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 41
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# ...

# %%
joined_Table.payment_method_id.isnull()==True
# Out:
# msno
# +++FOrTS7ab3tIgIh8eWwX4FqRv8w/FoiOuyXsFvphY=    False
# +++IZseRRiQS9aaSkH6cMYU6bGDcxUieAi/tH67sC5s=    False
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=    False
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=    False
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=    False
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=    False
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=    False
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=    False
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=    False
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=    False
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=    False
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=    False
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=    False
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=    False
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=    False
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=    False
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=    False
# ...

# %%
joined_Table[joined_Table.is_churn.isnull()].size
# Out:
# 50981382

# %%
joined_Table['payment_method_id'].hist()

# %%
pd.value_counts(joined_Table.payment_method_id)
# Out:
# 41    11526454
# 40     2225283
# 38     1703590
# 39     1466655
# 37     1007689
# 36      855115
# 34      731539
# 35      541399
# 33      411164
# 31      252342
# 30      160957
# 32      146481
# 29      113885
# 28       95733
# 27       62525
# 23       42386
# 19       32073
# 20       28278
# 21       22883
# 22       20130
# 24       16196
# 18       16177
# 25       13780
# 14       13621
# 16       11064
# 17        7437
# 13        6571
# 26        4591
# 12        3834
# 11        2129
# 15        1479
# 10        1326
# 7         1094
# 8          657
# 5          474
# 6          466
# 3          210
# 2           52
# 4           15
# 1           12
# Name: payment_method_id, dtype: int64

# %%
pd.value_counts(joined_Table.is_churn)
# Out:
# 0.0    15197577
# 1.0      685571
# Name: is_churn, dtype: int64

# %%
joined_Table['plan_list_price'].hist()

# %%
joined_Table['plan_list_price'].count
# Out:
# <bound method Series.count of msno
# +++FOrTS7ab3tIgIh8eWwX4FqRv8w/FoiOuyXsFvphY=       0
# +++IZseRRiQS9aaSkH6cMYU6bGDcxUieAi/tH67sC5s=    1788
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=      99
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=      99
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=      99
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=      99
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=     149
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=     149
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=     149
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=     149
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=     149
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=     149
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=     149
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=     149
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=     149
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=     149
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=     149
# ...

# %%
f.size
# Out:
# 1985862

# %%
f[f.is_churn==0].size
# Out:
# 1858920

# %%
f.describe()
# Out:
#             is_churn
# count  992931.000000
# mean        0.063923
# std         0.244616
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
f[f.is_churn==1].size
# Out:
# 126942

# %%
126942/1985862*100
# Out:
# 6.392287077349786

# %%
f.msno
# Out:
# 0         waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=
# 1         QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=
# 2         fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=
# 3         mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=
# 4         XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=
# 5         GBy8qSz16X5iYWD+3CMxv/Hm6OPSrXBYtmbnlRtknW0=
# 6         lYLh7TdkWpIoQs3i3o6mIjLH8/IEgMWP9r7OpsLX0Vo=
# 7         T0FF6lumjKcqEO0O+tUH2ytc+Kb9EkeaLzcVUiTr1aE=
# 8         Nb1ZGEmagQeba5E+nQj8VlQoWl+8SFmLZu+Y8ytIamw=
# 9         MkuWz0Nq6/Oq5fKqRddWL7oh2SLUSRe3/g+XmAWqW1Q=
# 10        I8dFN2EjFN1mt4Xel8WQX1/g7u6Dg4PBMHLkiDjhUS8=
# 11        0Ip2rzeoa44alqEw3daokOIJ5pRlKsuvSXpFiVfz6/U=
# 12        piVhWxrWDmiNQFY6x+geStHfdT+nyD9lgXq05MSi7So=
# 13        wEUOkYvyz3xTOx2p9z2Xcs4OzYsH/ZrNFUKZ+KFPf0M=
# 14        xt4EjWRyXBMgEgKBJy63klKN6wIIR31t1K771V2Glps=
# 15        QS3ob4zLlWcWzBIlbsd6lQIA3nJusPs6rNDVSEpQO2k=
# 16        9iW/UpqRoviya9CQh64RoYLPjiws8+biwscN+g5qYm4=
# ...

# %%
f.msno.unique
# Out:
# <bound method Series.unique of 0         waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=
# 1         QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=
# 2         fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=
# 3         mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=
# 4         XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=
# 5         GBy8qSz16X5iYWD+3CMxv/Hm6OPSrXBYtmbnlRtknW0=
# 6         lYLh7TdkWpIoQs3i3o6mIjLH8/IEgMWP9r7OpsLX0Vo=
# 7         T0FF6lumjKcqEO0O+tUH2ytc+Kb9EkeaLzcVUiTr1aE=
# 8         Nb1ZGEmagQeba5E+nQj8VlQoWl+8SFmLZu+Y8ytIamw=
# 9         MkuWz0Nq6/Oq5fKqRddWL7oh2SLUSRe3/g+XmAWqW1Q=
# 10        I8dFN2EjFN1mt4Xel8WQX1/g7u6Dg4PBMHLkiDjhUS8=
# 11        0Ip2rzeoa44alqEw3daokOIJ5pRlKsuvSXpFiVfz6/U=
# 12        piVhWxrWDmiNQFY6x+geStHfdT+nyD9lgXq05MSi7So=
# 13        wEUOkYvyz3xTOx2p9z2Xcs4OzYsH/ZrNFUKZ+KFPf0M=
# 14        xt4EjWRyXBMgEgKBJy63klKN6wIIR31t1K771V2Glps=
# 15        QS3ob4zLlWcWzBIlbsd6lQIA3nJusPs6rNDVSEpQO2k=
# 16        9iW/UpqRoviya9CQh64RoYLPjiws8+biwscN+g5qYm4=
# ...
